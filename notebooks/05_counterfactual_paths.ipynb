# %% [markdown]
# # 05 — §4.2 Counterfactual path experiments
# Each path is a shape added on a flat baseline (last realized value held over the 13-week horizon);
# the other macro axis is held flat except in the combined runs. Requires main-model checkpoints (notebook 03).
# - Liquidity: zero-mean ramps → same mean & variance (Tables 4.4.x)
# - Short rate: uptrend continuous vs discrete, same start/end (Tables 4.5.x)
# - Combined: discrete rate uptrend × liquidity ramps (Table 4.7)

# %%
from google.colab import drive; drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks/homeostatic-market
# !git pull
# !pip -q install nflows arch yfinance pandas-datareader

# %% [markdown]
# ## Liquidity paths (moment-matched)

# %%
# !PS_BASE=fpath_novol FPATH_DIM=2 python colab/dual_3ch/pathshape_zeromean_anchored_rawvol.py

# %% [markdown]
# ## Short-rate paths (uptrend, jump-free anchoring)

# %%
# !PS_BASE=fpath_novol FPATH_DIM=2 python colab/dual_3ch/pathshape_realized_anchored_rawvol.py

# %% [markdown]
# ## Combined paths

# %%
# !PS_BASE=fpath_novol FPATH_DIM=2 python colab/dual_3ch/pathshape_joint_ratestep_metabmm_k1.py
