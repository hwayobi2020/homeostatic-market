# %% [markdown]
# # 04 — Baselines: GARCH-ST, Conditional VAE / WGAN-GP, MAC-VAE

# %%
from google.colab import drive; drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks/homeostatic-market
# !git pull
# !pip -q install nflows arch yfinance pandas-datareader

# %% [markdown]
# ## Conditional VAE / Conditional GAN (WGAN-GP) — Table 15 (retuned spec; writes `result/thin_vg_cache`)

# %%
# !PS_BASE=fpath_novol FPATH_DIM=2 python colab/dual_3ch/run_thin_compare.py

# %% [markdown]
# ## GARCH-ST (past-information benchmark) — Table 13: initial fit, refit, evaluation

# %%
# !python colab/dual_3ch/train_garch_xpast.py
# !python colab/dual_3ch/refit_garch_xpast.py
# !python colab/dual_3ch/eval_garch_xpast_refit.py

# %% [markdown]
# ## MAC-VAE — MAC-Flow architecture with the flow head replaced by a conditional VAE head — Table 16 (tune → 5 seeds → comparison)

# %%
# !python colab/dual_3ch/run_macvae_all.py
