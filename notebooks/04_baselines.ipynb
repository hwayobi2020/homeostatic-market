# %% [markdown]
# # 04 — Baselines: Conditional VAE / WGAN-GP and GARCH-skew-t
# Trains the comparison models of §4.3 on the identical folds and evaluation pipeline.

# %%
from google.colab import drive; drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks/homeostatic-market
# !git pull
# !pip -q install nflows arch yfinance pandas-datareader

# %% [markdown]
# ## Conditional VAE / Conditional GAN (WGAN-GP) — Table 4.9

# %%
# !python colab/dual_3ch/run_vae_gan_all.py

# %% [markdown]
# ## GARCH-skew-t (past-information benchmark) — Table 4.8

# %%
# !python colab/dual_3ch/train_garch_xpast.py
