# %% [markdown]
# # 02 — Re-run inference from trained checkpoints
# Rebuilds the caches by re-sampling from the trained checkpoints (GPU required), then re-aggregates the tables.
# Seeds are fixed and sampling is paired-seed, so the resulting numbers should match the paper.
# **Prerequisite:** checkpoints produced by notebook 03 must exist under `result/` on this drive.

# %%
from google.colab import drive; drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks/homeostatic-market
# !git pull
# !pip -q install nflows arch yfinance pandas-datareader

# %% [markdown]
# ### (Optional) clear the caches to force full re-inference — uncomment deliberately

# %%
# !rm -rf result/*fpath_novol_d2*          # path-experiment / importance caches
# !rm -rf result/tail_ablation_cache*        # ablation caches

# %% [markdown]
# ### Re-run — identical commands to notebook 01; scripts recompute whatever cache is missing

# %%
# !PS_BASE=fpath_novol FPATH_DIM=2 python colab/dual_3ch/build_table_42_43_pooled.py
# !PS_BASE=fpath_novol FPATH_DIM=2 python colab/dual_3ch/pathshape_zeromean_anchored_rawvol.py
# !PS_BASE=fpath_novol FPATH_DIM=2 python colab/dual_3ch/pathshape_realized_anchored_rawvol.py
# !PS_BASE=fpath_novol FPATH_DIM=2 python colab/dual_3ch/pathshape_joint_ratestep_metabmm_k1.py
# !FPATH_DIM=2 TAIL_SEEDS=2026,2027,2028,2029,2030 python colab/dual_3ch/tail_ablation_bootstrap.py
# !PS_BASE=fpath_novol FPATH_DIM=2 python colab/dual_3ch/analyze_feature_importance_tail_rawvol.py
