# %% [markdown]
# # 01 — Reproduce the §4 tables from the caches written by notebooks 02–05
#
# No training here. Run `03`–`05` first (or use the caches on the training drive).

# %%
from google.colab import drive; drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks/homeostatic-market
# !git pull
# !pip -q install nflows arch yfinance pandas-datareader

# %% [markdown]
# ## Tables 12 / 26 — fit on realized macro paths, past-encoder ablation (JSON-only aggregation)

# %%
# !PS_BASE=fpath_novol FPATH_DIM=2 MAIN_TAG=rvAbl_full_fpath_novol_d2 python colab/dual_3ch/agg_section4.py

# %% [markdown]
# ## Tables 13 / 15 — MAC-Flow vs GARCH-ST and vs Conditional VAE / GAN (reads the caches written by notebook 04)

# %%
# !PS_BASE=fpath_novol FPATH_DIM=2 GARCH_PREFIX=garch_xpast_refit python colab/dual_3ch/report_tail_all.py

# %% [markdown]
# ## Tables 17 / 18 — level-based experiments on past paths (model-on-realized; liquidity / short-rate axes)

# %%
# !PS_BASE=fpath_novol FPATH_DIM=2 python colab/dual_3ch/build_table_42_43_pooled.py

# %% [markdown]
# ## Tables 19–23, A1 — hypothetical-path (shape) experiments (liquidity, short-rate uptrend, joint)

# %%
# !PS_BASE=fpath_novol FPATH_DIM=2 python colab/dual_3ch/pathshape_zeromean_anchored_rawvol.py
# !PS_BASE=fpath_novol FPATH_DIM=2 python colab/dual_3ch/pathshape_realized_anchored_rawvol.py
# !PS_BASE=fpath_novol FPATH_DIM=2 python colab/dual_3ch/pathshape_joint_ratestep_metabmm_k1.py

# %% [markdown]
# ## Table 24 — path-condition ablation (full / liquidity-drop / mask-all vs actual)

# %%
# !FPATH_DIM=2 TAIL_SEEDS=2026,2027,2028,2029,2030 python colab/dual_3ch/tail_ablation_bootstrap.py

# %% [markdown]
# ## Table 25 — permutation importance of past-encoder inputs

# %%
# !PS_BASE=fpath_novol FPATH_DIM=2 python colab/dual_3ch/analyze_feature_importance_tail_rawvol.py
